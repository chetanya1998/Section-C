# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im1=cv2.imread('images/im0.png',0)
im2=cv2.imread('images/im1.png',0)

# %%
ret, bw_img = cv2.threshold(im1,127,255,cv2.THRESH_BINARY)
ret2,bw_img2 = cv2.threshold(im2,127,255,cv2.THRESH_BINARY)

# %%
plt.imshow(bw_img)

# %%
plt.imshow(bw_img2)

# %%
image1=np.array(bw_img)
image2=np.array(bw_img2)

# %%
windowR=np.zeros((5,5))
windowL=np.zeros((5,5))

# %%
img1 = bw_img.reshape(100, 100)
img2 = bw_img2.reshape(100, 100)
# Calculate the absolute difference on each channel separately
dif = np.fabs(np.subtract(img2[:], img1[:]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-4b9e6c108696> in <module>
# ----> 1 img1 = bw_img.reshape(100, 100)
#       2 img2 = bw_img2.reshape(100, 100)
#       3 # Calculate the absolute difference on each channel separately
#       4 dif = np.fabs(np.subtract(img2[:], img1[:]))
#
# ValueError: cannot reshape array of size 168750 into shape (100,100)
